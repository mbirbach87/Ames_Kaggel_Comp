# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import statsmodels.api as sm

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
houses = pd.read_csv('trains.csv')
holdout_set = pd.read_csv('test.csv')

# %%
houses.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour    ...     Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl    ...                0         0     NaN   NaN
# 1       IR1          Lvl    ...                0         0     NaN   NaN
# 2       Reg          Lvl    ...                0         0     NaN   NaN
# 3       Reg          Lvl    ...                0         0     NaN   NaN
# 4       IR1          Lvl    ...                0         0     NaN   NaN
#
# ...

# %%
features = ['Overall Qual', 'Year Built']
x= houses [features]
y = houses ['SalePrice']

# %%
# Now, let's build our GLM
indep_vars = ['Overall Qual', 'Year Built']
X = sm.add_constant(houses[indep_vars])
y = houses.SalePrice

glm_logit = sm.GLM(y, 
                   X,
                   sm.families.Binomial(sm.families.links.logit))
results_logit = glm_logit.fit()
# Out:
# /Users/marcbirbach/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:879: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# /Users/marcbirbach/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:880: RuntimeWarning: divide by zero encountered in true_divide
#   n_endog_mu = self._clean((1. - endog) / (1. - mu))

# %%
results_logit.summary()
# Out:
# /Users/marcbirbach/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:879: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# /Users/marcbirbach/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:880: RuntimeWarning: divide by zero encountered in true_divide
#   n_endog_mu = self._clean((1. - endog) / (1. - mu))
# /Users/marcbirbach/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:932: RuntimeWarning: divide by zero encountered in true_divide
#   special.gammaln(n - y + 1) + y * np.log(mu / (1 - mu)) +
# /Users/marcbirbach/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:932: RuntimeWarning: divide by zero encountered in log
#   special.gammaln(n - y + 1) + y * np.log(mu / (1 - mu)) +
# /Users/marcbirbach/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:932: RuntimeWarning: invalid value encountered in add
# ...
